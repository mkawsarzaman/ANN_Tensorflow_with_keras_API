# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/kc_house_data.csv')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])
# Out:
# D:\Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# D:\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='sqft_living',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
#geographical properties

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values(by='price',ascending=False).head(30)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*1/100
# Out:
# 215.97

# %%
non_top_1_percent = df.sort_values(by='price',ascending=False).iloc[216:]

# %%
non_top_1_percent.head()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6329       8510     2.0           0     1  ...     10        3610
# 12271     23373     3.0           0     1  ...     11        5050
# 9166      12566     1.0           1     4  ...      8        1940
# 12565     31353     2.0           0     0  ...     12        4430
# 1150       7898     1.0           1     4  ...      8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_percent,hue='price',palette='RdYlBu')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df = df.drop('id',axis=1)
# as id does not give any suitable info

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
#converting datetime object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df.groupby(by='month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
#df = df.drop('date',axis=1)

# %%
df = df.drop('zipcode',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(correlation,cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
#scaling and train_test_split

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Activation

# %%
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
#arbitrary choice of width of layers
model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))
model.add(Dense(19,activation = 'relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),
          batch_size=128,epochs = 400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 2ms/step - loss: 430241349632.0000 - val_loss: 418925412352.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 977us/step - loss: 429297664000.0000 - val_loss: 415620136960.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 979us/step - loss: 416069484544.0000 - val_loss: 385619230720.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 968us/step - loss: 352034160640.0000 - val_loss: 281012404224.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 1ms/step - loss: 214362685440.0000 - val_loss: 136760401920.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 970us/step - loss: 113338310656.0000 - val_loss: 96462323712.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 98595938304.0000 - val_loss: 94593966080.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302413e+11  4.189254e+11
# 1    4.292977e+11  4.156201e+11
# 2    4.160695e+11  3.856192e+11
# 3    3.520342e+11  2.810124e+11
# 4    2.143627e+11  1.367604e+11
# ..            ...           ...
# 395  3.000302e+10  2.786656e+10
# 396  2.997293e+10  2.789305e+10
# 397  3.001308e+10  2.783863e+10
# 398  2.995492e+10  2.772971e+10
# 399  2.995475e+10  2.774930e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 103372.89956356096

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 166581.20902188605

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7908892662876148

# %%
plt.scatter(x=y_test,y=predictions)
plt.plot(y_test,y_test,'g')

# %%
y_test.shape
# Out:
# (6480,)

# %%
predictions.shape
# Out:
# (6480, 1)

# %%
y_test.reshape((6480,1)).shape
# Out:
# (6480, 1)

# %%
errors = y_test.reshape((6480,1)) - predictions

# %%
sns.displot(errors,kind='kde')

# %%
#predicting price of an unknown house

# %%
new_house = df.drop('price',axis=1).iloc[0]

# %%
new_house.shape
# Out:
# (19,)

# %%
new_house = scaler.transform(new_house.resha)
